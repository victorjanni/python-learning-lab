# %%
print("hi")
# Out:
# hi

# %%
L = [1,2,3,4,5]

# %%
# syntax to create an object
# ojectname = classname()

# %%
class Atm:
    # constructor (special function)->superpower ->
    def __init__(self):
        print(id(self))
        self.pin = ''
        self.balance = 0
        #self.menu()
    def menu(self):
        user_input = input("""
        Hi how can I help you?
        1.Press 1 to create pin
        2.Press 2 to change pin
        3.Press 3 to check balance
        4.Press 4 to withdraw cash
        5.Anything else to exit""") 

        if user_input == '1':
         self.create_pin()
        elif user_input == '2':
         self.change_pin() 
        elif user_input == '3':
         self.check_balance() 
        elif user_input == '4':
         self.withdraw_cash()
        else:
          exit()
    def create_pin(self):
      self.pin = input("enter your pin:")  
      self.balance = int(input("enter your balance")) 
      print("pin created successfully")   
      self.menu()

    def change_pin(self):
      old_pin = input("enter your old pin:")
      if old_pin == self.pin:
        self.pin = input("enter your new pin:")
        print("new pin created successfully")
        self.menu()
      else:
        print("you have entered wrong pin")
        self.menu()
    def check_balance(self):
      pin = input("enter your pin:") 
      if pin == self.pin:
        print("your account balance is:",self.balance()) 
        self.menu()
      else:
        print("you have entered wrong pin, please try again")
        self.menu()    

    def withdraw_cash(self):
      pin = input("enter your pin:") 
      if pin == self.pin:
        amount = int(input("enter the amount to withdraw:"))
        if amount<=self.balance:
          self.balance -= amount
          print("please collect your cash and your remaining balance is:",self.balance)
          self.menu()
        else:
          print("insufficient balance")
          self.menu()  
      else:
        print("you have entered wrong pin, please try again")
        self.menu()

# %%
obj = Atm()  # creating an object of class Atm
# Out:
# 2177001176416
